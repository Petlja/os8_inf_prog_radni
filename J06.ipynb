# %% [markdown]
# # Вежба 6. Табеларно представљени подаци
#
# У овој вежби ћемо говорити о:
# 1. ефикасном представљању табеларних података користећи библиотеку *pandas*,
# 2. визуелизацији табеларно представљених података, и
# 3. учитавању табела из локалних и удаљених ресурса.

# %% [markdown]
# ## 6.1. Библиотека *pandas*, структура података *DataFrame* и рад са колонама табеле
#
# За ефикасно манипулисање табеларно представљеним подацима у Пајтону развијена је библиотека *pandas*.

# %% [markdown]
# ### Задатак.
#
# Следећа табела садржи податке о једној групи деце (при чему је, наравно, старост изражена у годинама, тежина у килограмима, а висина у центиметрима):
#
# | **Ime** | **Pol** | **Starost** | **Masa** | **Visina** |
# |---|---|---|---|---|
# |      Ana | ž | 13 | 46 | 160 |
# |    Bojan | m | 14 | 52 | 165 |
# |    Vlada | m | 13 | 47 | 157 |
# |  Gordana | ž | 15 | 54 | 165 |
# |    Dejan | m | 15 | 56 | 163 |
# |    Đorđe | m | 13 | 45 | 159 |
# |    Elena | ž | 14 | 49 | 161 |
# |  Žaklina | ž | 15 | 52 | 164 |
# |    Zoran | m | 15 | 57 | 167 |
# |    Ivana | ž | 13 | 45 | 158 |
# |    Jasna | ž | 14 | 51 | 162 |
#
# У ћелији испод ова табеле је представљена низовима података:

# %%
podaci = [["Ana",     "ž", 13, 46, 160],
          ["Bojan",   "m", 14, 52, 165],
          ["Vlada",   "m", 13, 47, 157],
          ["Gordana", "ž", 15, 54, 165],
          ["Dejan",   "m", 15, 56, 163],
          ["Đorđe",   "m", 13, 45, 159],
          ["Elena",   "ž", 14, 49, 161],
          ["Žaklina", "ž", 15, 52, 164],
          ["Zoran",   "m", 15, 57, 167],
          ["Ivana",   "ž", 13, 45, 158],
          ["Jasna",   "ž", 14, 51, 162]]

# %% [markdown]
# Препакуј податке о деци у *DataFrame* позивом одговарајуће функције:

# %%
import pandas as pd
tabela = ??? # <--- овде унеси команду која ће од променљиве podaci направити DataFrame

# %% [markdown]
# Именуј колоне овако: "Ime", "Pol", "Starost", "Masa", "Visina"

# %%
tabela.columns = [???] # <--- овде унеси имена колона

# %% [markdown]
# Позивом одговарајуће функције израчунај колико је високо највише дете у групи:

# %%
   # <--- овде унеси одговарајућу команду

# %% [markdown]
# Позивом одговарајуће функције израчунај колико година има најмлађе дете у групи:

# %%
   # <--- овде унеси одговарајућу команду

# %% [markdown]
# Позивом одговарајуће функције израчунај просечну старост деце у групи:

# %%
   # <--- овде унеси одговарајућу команду

# %% [markdown]
# Да ли цела група може да стане у лифт чија носивост је 400 кг?

# %%
if ???:     # <--- уместо три упитника унеси одговарајућу команду
    print("Mogu svi da stanu u lift.")
else:
    print("Ne. Zajedno su preteški.")

# %% [markdown]
# ### Задатак.
#
# Ево трошкова живота једне породице током једне године, по месецима (сви износи су представљени у динарима):
#
#   | Stavka | Jan | Feb | Mar | Apr | Maj | Jun | Jul | Avg | Sep | Okt | Nov | Dec |
#   |--------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
#   | Stanarina | 8.251 | 8.436 | 8.524 | 8.388 | 8.241 | 8.196 | 8.004 | 7.996 | 7.991 | 8.015 | 8.353 | 8.456 |
#   | Struja | 4.321 | 4.530 | 4.115 | 3.990 | 3.985 | 3.726 | 3.351 | 3.289 | 3.295 | 3.485 | 3.826 | 3.834 |
#   | Telefon (fiksni) | 1.425 | 1.538 | 1.623 | 1.489 | 1.521 | 1.485 | 1.491 | 1.399 | 1.467 | 1.531 | 1.410 | 1.385 |
#   | Telefon (mobilni) | 2.181 | 2.235 | 2.073 | 1.951 | 1.989 | 1.945 | 3.017 | 2.638 | 2.171 | 1.831 | 1.926 | 1.833 |
#   | TV i internet | 2.399 | 2.399 | 2.399 | 2.399 | 2.399 | 2.399 | 2.399 | 2.399 | 2.399 | 2.399 | 2.399 | 2.399  |
#   | Prevoz | 1.830 | 1.830 | 1.830 | 1.830 | 1.950 | 1.950 | 1.450 | 1.450 | 1.950 | 1.950 | 2.050 | 2.050 |
#   | Hrana | 23.250 | 23.780 | 24.019 | 24.117 | 24.389 | 24.571 | 24.736 | 24.951 | 25.111 | 25.389 | 25.531 | 25.923 |
#   | Ostalo | 4.500 | 3.700 | 5.100 | 3.500 | 2.750 | 4.250 | 7.320 | 8.250 | 3.270 | 4.290 | 3.200 | 8.390 |
#
# У ћелији испод су исти подаци представљени листом:

# %%
troskovi = [
  ["Stanarina", 8251, 8436, 8524, 8388, 8241, 8196, 8004, 7996, 7991, 8015, 8353, 8456],
  ["Struja", 4321, 4530, 4115, 3990, 3985, 3726, 3351, 3289, 3295, 3485, 3826, 3834],
  ["Telefon (fiksni)", 1425, 1538, 1623, 1489, 1521, 1485, 1491, 1399, 1467, 1531, 1410, 1385],
  ["Telefon (mobilni)", 2181, 2235, 2073, 1951, 1989, 1945, 3017, 2638, 2171, 1831, 1926, 1833],
  ["TV i internet", 2399, 2399, 2399, 2399, 2399, 2399, 2399, 2399, 2399, 2399, 2399, 2399 ],
  ["Prevoz", 1830, 1830, 1830, 1830, 1950, 1950, 1450, 1450, 1950, 1950, 2050, 2050],
  ["Hrana", 23250, 23780, 24019, 24117, 24389, 24571, 24736, 24951, 25111, 25389, 25531, 25923],
  ["Ostalo", 4500, 3700, 5100, 3500, 2750, 4250, 7320, 8250, 3270, 4290, 3200, 8390]
]

# %% [markdown]
# *(а)* Представи табелу структуром *DataFrame* и именуј колоне.

# %% [markdown]
# *(б)* Израчунај и испиши *укупне* трошкове ове породице по месецима (колико је породица укупно потрошила у јануару, колико у фебруару итд).

# %% [markdown]
# ## 6.2. Визуелизација табеларно представљених података

# %% [markdown]
# ### Задатак.
#
# Представи хистограмом масу деце у групи из задатка у Одељку 6.1.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
plt.bar(???, ???) # <--- уместо упитника унеси одговарајуће групе података
plt.title("Masa dece u grupi")
plt.show()

# %% [markdown]
# ### Задатак.
#
# Производња кукуруза и пшенице у периоду 2008-2012. у Србији је дата у следећој табели (подаци су исказани у хиљадама тона):
#
# | Godina | Kukuruz | Pšenica |
# |--|--|--|
# | 2008. | 6.158 | 2.095 |
# | 2009. | 6.396 | 2.067 |
# | 2010. | 7.207 | 1.631 |
# | 2011. | 6.480 | 2.076 |
# | 2012. | 3.532 | 1.911 |
#
# *(а)* Направи одговарајући *DataFrame* па израчунај максималну производњу кукуруза и минималну производњу пшенице у наведеном периоду. (Упутство: податке прво представи листом, а онда од листе направи *DataFrame*.)

# %% [markdown]
# *(б)* На једном графикону прикажи стубичастим дијаграмом производњу пшенице и кукуруза у наведеном периоду. (Води рачуна да прво исцрташ податке за кукуруз, а онда преко тога податке за пшеницу.)

# %% [markdown]
# *(в)* Израчунај просечну годишњу производњу кукуруза за наведени период, као и за колико се разликовала производња пшенице у најбољој и најлошијој години наведеног периода (у хиљадама тона).

# %% [markdown]
# ### Задатак.
#
# У следећој листи су дати подаци о националним парковима Србије. За сваки национални парк је наведено његово име, површина у хектарима и година оснивања:

# %%
nac_parkovi = [["Fruška gora", 25393, 1960],
               ["Đerdap",      64000, 1974],
               ["Tara",        22000, 1981],
               ["Kopaonik",    11810, 1981],
               ["Šar-planina", 39000, 1985]]

# %% [markdown]
# *(а)* Од ове листе направи *DataFrame* па израчунај просечну површину националног парка (у хектарима), и укупну површину коју заузимају национални паркови у Србији (у квадратним километрима; 1 квадратни километар = 100 хектара).

# %% [markdown]
# *(б)* Прикажи линијским графиконом површине националних паркова у Србији.

# %% [markdown]
# ## 6.3. Учитавање података из локалних *CSV* датотека
#
# *CSV* датотека је текстуална датотека у којој редови одговарају редовима табеле, а подаци унутар истог реда су раздвојени зарезима. Име потиче од енгл. *comma separated values* што значи "вредности раздвојене зарезима".
#
# Библиотека `pandas` има функцију `read_csv` која учитава *CSV* датотеку и од ње прави табелу типа *DataFrame*.
#
#
# ### Задатак.
#
# У фолдеру *podaci* се налази датотека *Top25YouTubers.csv* која изгледа овако:
#
#     RANK,GRADE,NAME,VIDEOS,SUBSCRIBERS,VIEWES
#     1,A++,T-Series,13629,105783888,76945588449
#     2,A,PewDiePie,3898,97853589,22298927681
#     3,A+,5-Minute Crafts,3341,58629572,14860695079
#     4,A++,Cocomelon - Nursery Rhymes,441,53163816,33519273951
#     ...
#     25,A,TheEllenShow,10542,33362512,16519572219
#
# Ова табела садржи податке о 25 најпопуларнијих Јутјубера према броју претплатника на дан 1.7.2019. Први ред табеле представља заглавље табеле које нам каже да табела има шест колона (RANK, GRADE, NAME, VIDEOS, SUBSCRIBERS, VIEWES). Врста
#
#     4,A++,Cocomelon - Nursery Rhymes,441,53163816,33519273951
#
# значи да је на дан 1.7.2019. четврти по реду био Јутјуб канал са Јутјуб рангом А++ који се зове "Cocomelon - Nursery Rhymes" који је објавио укупно 441 видео на Јутјубу, који има 53.163.816 претплатника и 33.519.273.951 прегледа.
#
# Учитај библиотеку `pandas` па позивом функције `read_csv` учитај податке из ове датотеке. Напомена: пошто се датотека налази у фолдеру *podaci* пут до датотеке треба да изгледа овако:
#
#     podaci/Top25YouTubers.csv

# %% [markdown]
# Прикажимо првих десет редова ове табеле:

# %% [markdown]
# Прикажи последњих пет редова ове табеле:

# %% [markdown]
# Прикажи податке о броју претплатника стубичастим дијаграмом. Пошто су имена канала веома дугачка уместо функције `bar` користи функцију `barh` која ради исти посао, али стубиће исцртава хоризонтално:

# %% [markdown]
# ### Задатак.
#
# У датотеци *podaci/LEB.csv* налазе се подаци о очекиваној дужини живота особе у тренутку рођења (енгл. *Life Expectancy at Birth*), по петогодишњим периодима.

# %% [markdown]
# *(а)* Учитај датотеку у структуру података *DataFrame*.

# %% [markdown]
# *(б)* Прикажи ове податке стубичастим дијаграмом.

# %% [markdown]
# ### Задатак.
#
# Ученици једног разреда су скакали у даљ. Сваки ученик је скакао три пута и резултати су дати у датотеци *SkokUDalj.csv* која се налази у фолдеру *podaci*. Табела има заглавље и састоји се од четири колоне: "Презиме и име", "Скок1", "Скок2" и "Скок3".
#
# *(а)* Учитај датотеку у структуру података *DataFrame*.

# %% [markdown]
# *(б)* Прикажи ове податке стубичастим дијаграмом који ће имати три групе стубића, по једну за сваки скок. Дијаграм треба да има легенду.

# %% [markdown]
# ## 6.4. Учитавање података из удаљених ресурса
#
# Функција `read_csv` библиотеке `pandas` може податке да учитава и из удаљених ресурса. Потребно је само навести цео пут до датотеке са подацима, што се постиже навођењем комплетног *URL*-а (од енгл. *Universal Resource Locator*, што значи "Универзални локатор ресурса"), на пример овако:
#
#     https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv
#
# Слично томе, помоћу наредбе `read_html` може се прочитати и табела директно из *HTML* кода неке веб странице.
#
# ### Задатак.
#
# Учитај датотеку са горње адресе и прикажи првих петнаест редова табеле:

# %% [markdown]
#  Рецимо, следећа наредба чита списак свих федералних јединица Сједињених Америчких Држава са одговарајуће странице Википедије:

# %% [markdown]
# ### Задатак.
#
# На адреси
#
#     https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapminder-FiveYearData.csv
#
# се налази јавно доступна табела са списком држава света и неким параметрима економског развоја тих држава праћеним у интервалима од 5 година.
#
# Табела има следеће колоне:
#
# * country = држава
# * year = година на коју се односе подаци
# * pop = број становника (енгл. *population*)
# * continent = континент
# * lifeExp = очекивани животни век у годинама (енгл. *life expextancy*)
# * gdpPercap = БДП по глави становника у америчким доларима (енгл. *GDP per capitem*)
#
# Учитај ову табелу у структуру података *DataFrame* и прикажи првих 20 редова табеле, као и последњих 10 редова табеле.

# %% [markdown]
# ### Задатак*.
#
# Са следеће адресе
#
#     https://www.worldometers.info/world-population/population-by-country/
#
# функцијом `read_html` учитај табелу која садржи податке о свим државама на свету и броју њихових становника. Прикажи првих и последњеих неколико редова табеле. Немој заборавити да функција `read_html` враћа *листу табела*, а теби треба први елемент те листе:
